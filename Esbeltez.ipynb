# %% [markdown]
# ## Cálculo de esbeltez de elementos de acuerdo con NCh427-1
# ### 1. Miembros en compresión

# %%
import modulo_esbeltez as esbeltez

#Perfil tubular
elem1 = esbeltez.Elemento_en_compresion_por_compresion(D=200, t=3)
print(elem1.caso9())

#Alas perfil H
elem2 = esbeltez.Elemento_en_compresion_por_compresion(b=200, t=5)
print(elem2.caso1())

#Alma seccion T
elem3 = esbeltez.Elemento_en_compresion_por_compresion(d=250, t=15)
print(elem3.caso4())
# Out:
# 100.0
# 89.94157330193251
# 125.5602871702901
# No Compacto - No Esbelto
# Elemento Circular esbelto
# True
# Elemento Ala esbelto
# True
# Elemento Alma T no esbelto
# False

# %% [markdown]
# ### 2. Elemento en compresión por flexión

# %%
#Para perfil H soldado
elem1 = esbeltez.Elemento_en_compresion_por_flexion(
    h = 500, #mm
    bfs = 300, #mm
    bfi = 300, #mm
    tfs = 28, #mm
    tfi = 28, #mm
    tw = 20 #mm
)
print(elem1.caso11())
# Out:
# kc = 0.76
# Sxt/Sxc = 1.0 => FL = 2940.0
# Compacto - No Esbelto

# %%
elem2 = esbeltez.Elemento_en_compresion_por_flexion(
    h = 500, #mm
    bfs = 300, #mm
    bfi = 300, #mm
    tfs = 10, #mm
    tfi = 10, #mm
    tw = 5 #mm
)
print(elem2.caso16())
# Out:
# 100.0
# 89.94157330193251
# 125.5602871702901
# No Compacto - No Esbelto

# %%
elem3 = esbeltez.Elemento_en_compresion_por_flexion(D=500, t=3)
print(elem3.caso20())
# Out:
# No Compacto - Esbelto
