# %%
from modulo_secciones_acero import Perfilhsoldado
from diseno_traccion import flexion

perfil = Perfilhsoldado(200, 200, 5, 5, 5, 5)
traccionLRFD = flexion(perfil, "LRFD")
traccionASD = flexion(perfil, "ASD")
print("Tracción admisible por LRFD")
print(f"Area = {perfil.A()/10**2} cm2")
print(f"phiPn = {traccionLRFD:.0f} kgf = {traccionLRFD/1000:.2f} tonf")
print("\nTracción admisible por ASD")
print(f"Area = {perfil.A()/10**2} cm2")
print(f"phiPn = {traccionASD:.0f} kgf = {traccionASD/1000:.2f} tonf")
# Out:
# Tracción admisible por LRFD
# Area = 20.25 cm2
# phiPn = 56925 kgf = 56.92 tonf
#
# Tracción admisible por ASD
# Area = 20.25 cm2
# phiPn = 30678 kgf = 30.68 tonf
